# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

df = pd.read_csv('synthetic_dataset.csv')

filtered_df = df[df['mastercard_si_abbr'].astype(str).str.startswith(('44', '45'))]

income_data = pd.read_csv('ACSDP1Y2022.DP03-Data.csv')

# %%
print(filtered_df)
# Out:
#               date  mastercard_si_abbr county_fips  total_spend  card_count  \
# 0       2023-09-17                 447       48315       498.84           3
# 4       2022-06-26                 443       47053       949.20           2
# 6       2021-04-02                 446       16000       292.06           2
# 7       2021-11-26                 443       45055       214.07           3
# 12      2023-06-03                 454       29215       328.77           3
# ...            ...                 ...         ...          ...         ...
# 999988  2022-05-09                 444       47017       548.74           2
# 999993  2021-04-08                 441       23019       858.64           3
# 999995  2021-07-22                 441       39059       839.79           3
# 999996  2021-09-16                 452       30047       893.25           1
# 999999  2021-03-07                 448       47127       149.13           1
#
#         income_quartile
# 0                     1
# 4                     4
# 6                     1
# 7                     1
# 12                    1
# ...                 ...
# 999988                2
# 999993                4
# 999995                2
# 999996                1
# 999999                2
#
# [342740 rows x 6 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

filtered_df['date'] = pd.to_datetime(filtered_df['date'])

filtered_df['income_quartile'] = pd.to_numeric(filtered_df['income_quartile'])

income_data['extracted_fips'] = income_data['GEO_ID'].str[-5:]

merged_df = pd.merge(filtered_df, income_data[['extracted_fips', 'DP03_0062E']],
                     left_on='county_fips', right_on='extracted_fips', how='inner')

merged_df.rename(columns={'DP03_0062E': 'median_income'}, inplace=True)

merged_df.drop('extracted_fips', axis=1, inplace=True)

merged_df['median_income'] = pd.to_numeric(merged_df['median_income'], errors='coerce')

# Define the function to analyze spending and card count for each quartile
def analyze_spending_and_card_count_for_quartile(quartile):
    # Filter dataframe for the current quartile
    df_filtered = merged_df[merged_df['income_quartile'] == quartile]
    
    # Compute monthly spending and card count
    monthly_spending = df_filtered.resample('M', on='date')['total_spend'].sum()
    monthly_card_count = df_filtered.resample('M', on='date').size()
    
    # Compute percentage changes
    monthly_spending_change = monthly_spending.pct_change() * 100
    monthly_card_count_change = monthly_card_count.pct_change() * 100
    
    yearly_spending_change = monthly_spending.pct_change(periods=12) * 100
    yearly_card_count_change = monthly_card_count.pct_change(periods=12) * 100
    
    # Adjust spending changes by the card count changes
    adjusted_monthly_spending_change = monthly_spending_change - monthly_card_count_change
    adjusted_yearly_spending_change = yearly_spending_change - yearly_card_count_change
    
    # Plotting
    adjusted_monthly_spending_change.plot(kind='bar', figsize=(12, 6), title=f'Adjusted Monthly Spending Change for Quartile {quartile}')
    plt.xlabel('Month')
    plt.ylabel('Adjusted Spending Change (%)')
    plt.xticks(rotation=45)
    plt.show()
    
    adjusted_yearly_spending_change.plot(kind='bar', figsize=(12, 6), title=f'Adjusted Yearly Spending Change for Quartile {quartile}')
    plt.xlabel('Month')
    plt.ylabel('Adjusted Spending Change (%)')
    plt.xticks(rotation=45)
    plt.show()
    
    # Printing cleaned data
    print(f"Adjusted Monthly Spending Change for Quartile {quartile} (cleaned):\n", adjusted_monthly_spending_change.dropna())
    print(f"Adjusted Yearly Spending Change for Quartile {quartile} (cleaned):\n", adjusted_yearly_spending_change.dropna())

# Analyze spending and card count changes for each quartile
for quartile in range(1, 5):  # Loop through quartiles 1 to 4
    analyze_spending_and_card_count_for_quartile(quartile)
# Out:
# /var/folders/w3/px1drxv124g_z3hn3m801cz40000gn/T/ipykernel_55057/1258366575.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['date'] = pd.to_datetime(filtered_df['date'])
# /var/folders/w3/px1drxv124g_z3hn3m801cz40000gn/T/ipykernel_55057/1258366575.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['income_quartile'] = pd.to_numeric(filtered_df['income_quartile'])
# Adjusted Monthly Spending Change for Quartile 1 (cleaned):
#  date
# 2019-02-28    -1.021550
# 2019-03-31    10.344517
# 2019-04-30    -6.962328
# 2019-05-31     0.760125
# 2019-06-30     1.112082
#                 ...
# 2023-10-31    -2.461564
# 2023-11-30    -7.846475
# 2023-12-31    11.618570
# 2024-01-31    -4.193944
# 2024-02-29     1.948299
# Freq: M, Length: 61, dtype: float64
# Adjusted Yearly Spending Change for Quartile 1 (cleaned):
#  date
# 2020-01-31     2.390454
# 2020-02-29     4.532413
# 2020-03-31    -8.997161
# 2020-04-30     6.934542
# 2020-05-31    -2.124733
# 2020-06-30     0.490590
# 2020-07-31     8.091661
# 2020-08-31    -1.278675
# 2020-09-30    -2.193695
# 2020-10-31    -1.214812
# 2020-11-30    -0.867714
# 2020-12-31    -4.094245
# 2021-01-31     0.009083
# 2021-02-28    -0.885465
# 2021-03-31     4.711213
# 2021-04-30    -3.259493
# 2021-05-31    -0.810563
# 2021-06-30     1.290502
# 2021-07-31     0.406259
# 2021-08-31    -2.984355
# 2021-09-30    -4.670931
# 2021-10-31     4.230126
# 2021-11-30    -2.549180
# 2021-12-31    -1.003552
# 2022-01-31     1.038484
# 2022-02-28    -1.172648
# 2022-03-31     1.242112
# 2022-04-30    -4.284725
# 2022-05-31     5.424383
# 2022-06-30    -3.854729
# 2022-07-31    -8.670588
# 2022-08-31    -2.095042
# 2022-09-30     4.659435
# 2022-10-31    -6.102505
# 2022-11-30     4.314998
# 2022-12-31    -0.667187
# 2023-01-31    -4.279167
# 2023-02-28    -1.893777
# 2023-03-31    -4.131344
# 2023-04-30     1.030693
# 2023-05-31    -2.783128
# 2023-06-30     3.968349
# 2023-07-31    -6.163846
# 2023-08-31     8.308005
# 2023-09-30     3.861204
# 2023-10-31     0.584534
# 2023-11-30   -10.269756
# 2023-12-31     0.837481
# 2024-01-31    -0.607215
# 2024-02-29     2.085002
# Freq: M, dtype: float64
# Adjusted Monthly Spending Change for Quartile 2 (cleaned):
#  date
# 2019-02-28    2.432706
# 2019-03-31    1.686430
# 2019-04-30   -3.098440
# 2019-05-31   -4.583687
# 2019-06-30   -1.150250
#                 ...
sigma, loc, scale = lognorm.fit(positive_incomes, floc=0)

mu = np.log(scale)  # Convert scale back to mu for the underlying normal distribution
# Sigma (standard deviation) of the log values is the same as the 'sigma' parameter from the fit

print(f"Mean (mu) of the logarithms of the data: {mu}")
print(f"Standard deviation (sigma) of the logarithms of the data: {sigma}")

n, bins, patches = plt.hist(positive_incomes, bins=30, density=True, alpha=0.5, label='Data', color='blue')

# Step 2: Calculate the PDF of the fitted log-normal distribution
# Generate a range of values from the minimum to the maximum income
x = np.linspace(positive_incomes.min(), positive_incomes.max(), 100)
# Calculate PDF values for these points
pdf_values = lognorm.pdf(x, s=sigma, loc=loc, scale=scale)

# Step 3: Plot the PDF on the same plot as the histogram
plt.plot(x, pdf_values, 'r-', lw=2, label='Log-normal fit')

# Add labels and a legend
plt.xlabel('Median Income')
plt.ylabel('Density')
plt.title('Fit of Median Income to Log-normal Distribution')
plt.legend()

# Show the plot
plt.show()
# Out:
# Mean (mu) of the logarithms of the data: 11.186443565039765
# Standard deviation (sigma) of the logarithms of the data: 0.24171711125056963

# %%
print(merged_df)
# Out:
#             date  mastercard_si_abbr county_fips  total_spend  card_count  \
# 0     2019-05-01                 452       37157       424.42           1
# 1     2023-10-11                 447       37157        19.84           3
# 2     2020-08-27                 452       37157       697.00           3
# 3     2021-03-24                 448       37157       854.29           2
# 4     2019-05-14                 445       37157       192.69           1
# ...          ...                 ...         ...          ...         ...
# 86823 2023-01-28                 448       40031       627.05           2
# 86824 2019-11-12                 454       40031       752.54           2
# 86825 2022-07-27                 454       40031       162.08           2
# 86826 2023-07-22                 448       40031       107.50           2
# 86827 2019-11-16                 447       40031       139.28           1
#
#        median_income income_category
# 0              51310        below_q1
# 1              51310        below_q1
# 2              51310        below_q1
# 3              51310        below_q1
# 4              51310        below_q1
# ...              ...             ...
# 86823          55285        below_q1
# 86824          55285        below_q1
# 86825          55285        below_q1
# 86826          55285        below_q1
# 86827          55285        below_q1
#
# [86828 rows x 7 columns]

# %%
print(merged_df)
# Out:
#             date  mastercard_si_abbr county_fips  total_spend  card_count  \
# 0     2021-11-26                 443       45055       214.07           3
# 1     2019-04-09                 443       45055       520.05           3
# 2     2019-02-27                 443       45055       673.43           1
# 3     2022-09-22                 443       45055       185.64           3
# 4     2019-09-29                 453       45055       916.67           3
# ...          ...                 ...         ...          ...         ...
# 86631 2023-11-14                 447       04005       382.81           2
# 86632 2019-06-07                 442       04005       506.54           2
# 86633 2021-04-28                 454       04005        21.95           2
# 86634 2023-08-06                 453       04005        36.61           2
# 86635 2022-05-04                 446       04005       313.33           1
#
#        income_quartile  median_income
# 0                    1          58684
# 1                    2          58684
# 2                    1          58684
# 3                    4          58684
# 4                    1          58684
# ...                ...            ...
# 86631                1          62622
# 86632                4          62622
# 86633                2          62622
# 86634                4          62622
# 86635                4          62622
#
# [86636 rows x 7 columns]
