# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import norm

df = pd.read_csv('ACSDP1Y2022.DP03-Data.csv')

df['DP03_0062E'] = pd.to_numeric(df['DP03_0062E'], errors='coerce')
df.dropna(subset=['DP03_0062E'], inplace=True)

mu, std = norm.fit(df['DP03_0062E'])

print(f'Normal distribution parameters: mean = {mu}, standard deviation = {std}')

plt.figure(figsize=(10, 6))
plt.hist(df['DP03_0062E'], bins=30, density=True, alpha=0.6, color='g')

xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
p = norm.pdf(x, mu, std)
plt.plot(x, p, 'k', linewidth=2)
title = f"Fit results: mu = {mu:.2f},  std = {std:.2f}"
plt.title(title)

plt.show()
# Out:
# Normal distribution parameters: mean = 73816.02476415095, standard deviation = 19769.606120590815

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import norm

df = pd.read_csv('ACSDP1Y2022.DP03-Data.csv')

df['DP03_0062E'] = pd.to_numeric(df['DP03_0062E'], errors='coerce')
df.dropna(subset=['DP03_0062E'], inplace=True)

df['Log_DP03_0062E'] = np.log(df['DP03_0062E'])
mu, std = norm.fit(df['Log_DP03_0062E'])
print(f'Log-normal distribution parameters: mean = {mu}, standard deviation = {std}')

plt.figure(figsize=(10, 6))
plt.hist(df['Log_DP03_0062E'], bins=30, density=True, alpha=0.6, color='g')

xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
p = norm.pdf(x, mu, std)
plt.plot(x, p, 'k', linewidth=2)
title = f"Log Fit results: mu = {mu:.2f}, std = {std:.2f}"
plt.title(title)

plt.show()
# Out:
# Log-normal distribution parameters: mean = 11.174517621077012, standard deviation = 0.26622430663569263
